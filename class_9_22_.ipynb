# %% [markdown]
# <a href="https://colab.research.google.com/github/alkalink1/ds1002-eju2pk/blob/main/class_9_22_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# import mockaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   ip_address  1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
mock_data.head()
# Out:
#    id first_name last_name                     email  gender      ip_address
# 0   1      Vilma     Frane     vfrane0@clickbank.net  Female   79.172.12.221
# 1   2    Ramonda    Morris         rmorris1@digg.com  Female    37.243.1.181
# 2   3     Sianna     Renon     srenon2@reference.com  Female    62.2.125.193
# 3   4      Sylas     Ovill     sovill3@mediafire.com    Male  116.111.73.112
# 4   5     Kathie  Aindrais  kaindrais4@shinystat.com  Female  218.70.114.225

# %%
mock_data.tail()
# Out:
#        id  first_name  last_name                     email       gender  \
# 995   996       Arden      Negus   anegusrn@feedburner.com       Female
# 996   997   Zechariah      Poate          zpoatero@icq.com         Male
# 997   998        Tito   McGibbon  tmcgibbonrp@google.co.uk         Male
# 998   999      Ardeen      Brice    abricerq@people.com.cn  Genderfluid
# 999  1000  Bernadette  Duckworth      bduckworthrr@ihg.com       Female
#
#          ip_address
# 995   72.172.240.59
# 996   56.117.46.137
# 997  146.172.175.74
# 998   52.137.180.32
# 999  125.173.145.64

# %%
mock_data.loc[9]
# Out:
# id                              10
# first_name                Christin
# last_name                 Eighteen
# email         ceighteen9@wired.com
# gender                  Non-binary
# ip_address          232.207.42.103
# Name: 9, dtype: object

# %%
mock_data.describe()
# Out:
#                 id
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
# get the columns from the df
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address'], dtype='object')

# %%
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# ip_address    object
# dtype: object

# %%
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})

# %%
mock_data["fname"]
# Out:
# 0           Vilma
# 1         Ramonda
# 2          Sianna
# 3           Sylas
# 4          Kathie
#           ...
# 995         Arden
# 996     Zechariah
# 997          Tito
# 998        Ardeen
# 999    Bernadette
# Name: fname, Length: 1000, dtype: object

# %%
mock_data[["fname","lname"]]
# Out:
#           fname      lname
# 0         Vilma      Frane
# 1       Ramonda     Morris
# 2        Sianna      Renon
# 3         Sylas      Ovill
# 4        Kathie   Aindrais
# ..          ...        ...
# 995       Arden      Negus
# 996   Zechariah      Poate
# 997        Tito   McGibbon
# 998      Ardeen      Brice
# 999  Bernadette  Duckworth
#
# [1000 rows x 2 columns]

# %%
pd.value_counts(mock_data['gender']).plot.bar()
# Out:
# <Axes: >

# %%
mock_data.groupby(["gender"])["age"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-c64a66299a29> in <cell line: 1>()
# ----> 1 mock_data.groupby(["gender"])["age"].mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1414                 stacklevel=find_stack_level(),
#    1415             )
# -> 1416         return super().__getitem__(key)
#    1417
#    1418     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     246         else:
#     247             if key not in self.obj:
# --> 248                 raise KeyError(f"Column not found: {key}")
#     249             subset = self.obj[key]
#     250             ndim = subset.ndim
#
# KeyError: 'Column not found: age'
